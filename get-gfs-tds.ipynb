# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from mpl_toolkits.basemap import Basemap

# %%
# file = 'https://thredds.rda.ucar.edu/thredds/dodsC/files/g/ds084.1/2024/20240516/gfs.0p25.2024051600.f000.grib2'
file = 'https://thredds.ucar.edu/thredds/dodsC/grib/NCEP/GFS/Global_0p25deg/GFS_Global_0p25deg_20240517_0000.grib2'
ds = xr.open_dataset(file)

# %%
ds
# Out:
# <xarray.Dataset> Size: 398GB
# Dimensions:                                                                     (
#                                                                                  lat: 721,
#                                                                                  lon: 1440,
#                                                                                  time: 128,
#                                                                                  time1: 128,
#                                                                                  time2: 129,
#                                                                                  ...
#                                                                                  height_above_ground_layer_bounds_1: 2,
#                                                                                  height_above_ground_layer1_bounds_1: 2,
# ...

# %%
ds['u-component_of_wind_maximum_wind']
# Out:
# <xarray.DataArray 'u-component_of_wind_maximum_wind' (time: 1, lat: 721,
#                                                       lon: 1440)> Size: 4MB
# [1038240 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 3kB 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * lon      (lon) float32 6kB 0.0 0.25 0.5 0.75 1.0 ... 359.0 359.2 359.5 359.8
#     reftime  datetime64[ns] 8B ...
#   * time     (time) datetime64[ns] 8B 2024-05-16
# Attributes: (12/13)
#     long_name:                       u-component of wind @ Maximum wind level
#     units:                           m/s
#     abbreviation:                    UGRD
#     grid_mapping:                    LatLon_Projection
#     Grib_Variable_Id:                VAR_0-2-2_L6
#     Grib2_Parameter:                 [0 2 2]
#     ...                              ...
#     Grib2_Parameter_Category:        Momentum
#     Grib2_Parameter_Name:            u-component of wind
#     Grib2_Level_Type:                6
# ...
